# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot 
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
#Read dataset 

data_set = pd.read_csv(r'C:\Users\dell\OneDrive\Desktop\AI\AI data\Practice file by sir\Datasets\dirty_cafe_sales.csv')

df= pd.DataFrame(data_set)

display(df.head(10))
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# ...

# %%
plot.figure(figsize=(25,25))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
null_values = df.isnull().sum()/df.shape[0]*100
null_values
# Out:
# Transaction ID       0.00
# Item                 3.33
# Quantity             1.38
# Price Per Unit       1.79
# Total Spent          1.73
# Payment Method      25.79
# Location            32.65
# Transaction Date     1.59
# dtype: float64

# %%
df.shape
# Out:
# (10000, 8)

# %%
drop_columns = null_values[null_values> 20].keys()
drop_columns
# Out:
# Index(['Payment Method', 'Location'], dtype='object')

# %%
df= df.drop(columns = drop_columns)

df.shape
# Out:
# (10000, 6)

# %%
plot.figure(figsize=(25,25))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Transaction Date  9841 non-null   object
# dtypes: object(6)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_6170729  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#        Transaction Date
# count              9841
# unique              367
# top             UNKNOWN
# freq                159

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent Transaction Date
# 0    TXN_1961373  Coffee        2            2.0         4.0       2023-09-08
# 1    TXN_4977031    Cake        4            3.0        12.0       2023-05-16
# 2    TXN_4271903  Cookie        4            1.0       ERROR       2023-07-19
# 3    TXN_7034554   Salad        2            5.0        10.0       2023-04-27
# 4    TXN_3160411  Coffee        2            2.0         4.0       2023-06-11

# %%
df.tail()
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#      Transaction Date
# 9995       2023-08-30
# 9996       2023-06-02
# 9997       2023-03-02
# 9998       2023-12-02
# 9999       2023-11-07

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Transaction Date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Transaction Date    object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df['Transaction Date'] = pd.to_datetime(df['Transaction Date'],format='mixed')


#stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# %%
df['Item'].value_counts()
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# ERROR        292
# Name: count, dtype: int64

# %%
df['Item'] = df['Item'].ffill()


df['Item'].isnull().sum()
# Out:
# np.int64(0)

# %%
print("\n" + "="*60)

# %%
plot.figure(figsize=(25,25))
sns.heatmap(df.isnull())



plot.Figure(figsize=(20,20))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Transaction Date    object
# dtype: object

# %%
df.isnull().sum()/ 100
# Out:
# Transaction ID      0.00
# Item                0.00
# Quantity            1.38
# Price Per Unit      1.79
# Total Spent         1.73
# Transaction Date    1.59
# dtype: float64

# %%
print(f'Total number of rows: ',df.shape[0])
# Out:
# Total number of rows:  10000

# %%
print(f'Total number of coulmns: ',df.shape[1])
# Out:
# Total number of coulmns:  6

# %%
print(f'Data type of each coulmn: ', df.dtypes)
# Out:
# Data type of each coulmn:  Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Transaction Date    object
# dtype: object

# %%
#df['Quantity']= pd.to_numeric(df['Quantity'])

# %%
# missing_values = ['CGPA','Attendance_Rate' ]

# for col in missing_values:
#     student_data[col] = student_data[col].fillna(student_data[col].mod(0))

#     student_data['CGPA'] = student_data['CGPA'].fillna(student_data['CGPA'].mod(0))
#     student_data['Attendance_Rate'] = student_data['Attendance_Rate'].fillna(student_data['Attendance_Rate'].mod(0))

#     display(student_data.isnull().sum())

# %%
df.isnull().sum()
# Out:
# Transaction ID        0
# Item                  0
# Quantity            138
# Price Per Unit      179
# Total Spent         173
# Transaction Date    159
# dtype: int64

# %%
df['Transaction Date']
# Out:
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11
# 5       2023-03-31
# 6       2023-10-06
# 7       2023-10-28
# 8       2023-07-28
# 9       2023-12-31
# 10      2023-11-07
# 11           ERROR
# 12      2023-05-03
# 13      2023-06-01
# 14      2023-03-21
# 15      2023-11-15
# 16      2023-06-10
# 17      2023-02-24
# 18      2023-03-25
# 19      2023-01-15
# 20      2023-04-04
# 21      2023-03-30
# 22      2023-12-01
# 23      2023-09-18
# 24      2023-06-03
# 25      2023-12-13
# 26      2023-04-20
# 27      2023-04-10
# 28      2023-03-11
# 29           ERROR
# 30      2023-06-02
# 31      2023-11-06
# 32      2023-08-15
# 33           ERROR
# 34      2023-10-09
# 35      2023-05-28
# 36      2023-07-17
# 37      2023-04-29
# 38      2023-06-08
# 39      2023-06-29
# 40      2023-04-17
# 41      2023-12-22
# 42      2023-01-10
# 43      2023-10-02
# 44      2023-02-23
# 45      2023-03-22
# 46      2023-11-03
# ...

# %%
# stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# date = stock_data.sort_values('Date')
# display(date['Date'])

df['Transaction Date'] = pd.to_datetime(df['Transaction Date'],errors='coerce')

date = df.sort_values('Transaction Date')

display(df['Transaction Date'])
# Out:
# 0      2023-09-08
# 1      2023-05-16
# 2      2023-07-19
# 3      2023-04-27
# 4      2023-06-11
# 5      2023-03-31
# 6      2023-10-06
# 7      2023-10-28
# 8      2023-07-28
# 9      2023-12-31
# 10     2023-11-07
# 11            NaT
# 12     2023-05-03
# 13     2023-06-01
# 14     2023-03-21
# 15     2023-11-15
# 16     2023-06-10
# 17     2023-02-24
# 18     2023-03-25
# 19     2023-01-15
# 20     2023-04-04
# 21     2023-03-30
# 22     2023-12-01
# 23     2023-09-18
# 24     2023-06-03
# 25     2023-12-13
# 26     2023-04-20
# 27     2023-04-10
# 28     2023-03-11
# 29            NaT
# 30     2023-06-02
# 31     2023-11-06
# 32     2023-08-15
# 33            NaT
# 34     2023-10-09
# 35     2023-05-28
# 36     2023-07-17
# 37     2023-04-29
# 38     2023-06-08
# 39     2023-06-29
# 40     2023-04-17
# 41     2023-12-22
# 42     2023-01-10
# 43     2023-10-02
# 44     2023-02-23
# 45     2023-03-22
# 46     2023-11-03
# 47     2023-03-02
# 48     2023-06-26
# 49     2023-05-02
# ...

# %%
df.dtypes
# Out:
# Transaction ID              object
# Item                        object
# Quantity                    object
# Price Per Unit              object
# Total Spent                 object
# Transaction Date    datetime64[ns]
# dtype: object

# %%
#df.head(100)

# pd.set_option('display.max_rows', None)## shows all rows without dots 
pd.set_option('display.max_rows', None)
df.Item.count()
# Out:
# np.int64(10000)

# %%
df.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867  Sandwich        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11
# 5       2023-03-31
# 6       2023-10-06
# 7       2023-10-28
# 8       2023-07-28
# 9       2023-12-31

# %%
df['Quantity']= pd.to_numeric(df['Quantity'], errors='coerce').astype('Int64')

df['Quantity'].dtype
# Out:
# Int64Dtype()

# %%
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce').astype('float64')


df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce').astype('float64')

df.dtypes
# Out:
# Transaction ID              object
# Item                        object
# Quantity                     Int64
# Price Per Unit             float64
# Total Spent                float64
# Transaction Date    datetime64[ns]
# dtype: object

# %%
df['Item'].value_counts().sum()
# Out:
# np.int64(10000)

# %%
df['Item'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10000 entries, 0 to 9999
# Series name: Item
# Non-Null Count  Dtype
# --------------  -----
# 10000 non-null  object
# dtypes: object(1)
# memory usage: 78.3+ KB

# %%
df['Item'].describe()
# Out:
# count     10000
# unique       10
# top       Juice
# freq       1215
# Name: Item, dtype: object

# %%
df['Item'].value_counts()

#df['Item'] = df['Items'].replace()
# Out:
# Item
# Juice       1215
# Coffee      1204
# Salad       1179
# Cake        1176
# Sandwich    1168
# Smoothie    1139
# Tea         1130
# Cookie      1130
# UNKNOWN      358
# ERROR        301
# Name: count, dtype: int64

# %%
df['Item'] = df['Item'].ffill(inplace=False)

# %%
df['Item'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Quantity'] = df['Quantity'].ffill()

df['Quantity'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 5    2112
# 2    2069
# 3    1961
# 4    1951
# 1    1907
# Name: count, dtype: Int64

# %%
df['Quantity'].unique()
# Out:
# <IntegerArray>
# [2, 4, 5, 3, 1]
# Length: 5, dtype: Int64

# %%
df['Quantity'].nunique()
# Out:
# 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              10000 non-null  object
#  2   Quantity          10000 non-null  Int64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9498 non-null   float64
#  5   Transaction Date  9540 non-null   datetime64[ns]
# dtypes: Int64(1), datetime64[ns](1), float64(2), object(2)
# memory usage: 478.6+ KB

# %%
df['Transaction ID'].value_counts().sum()
# Out:
# np.int64(10000)

# %%
df['Item'].value_counts()
# Out:
# Item
# Juice       1215
# Coffee      1204
# Salad       1179
# Cake        1176
# Sandwich    1168
# Smoothie    1139
# Tea         1130
# Cookie      1130
# UNKNOWN      358
# ERROR        301
# Name: count, dtype: int64

# %%
df['Price Per Unit'].value_counts()
# Out:
# Price Per Unit
# 3.0    2429
# 4.0    2331
# 2.0    1227
# 5.0    1204
# 1.0    1143
# 1.5    1133
# Name: count, dtype: int64

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 5    2112
# 2    2069
# 3    1961
# 4    1951
# 1    1907
# Name: count, dtype: Int64

# %%
df['Total Spent'].value_counts()
# Out:
# Total Spent
# 6.0     979
# 12.0    939
# 3.0     930
# 4.0     923
# 20.0    746
# 15.0    734
# 8.0     677
# 10.0    524
# 2.0     497
# 9.0     479
# 5.0     468
# 16.0    444
# 25.0    259
# 7.5     237
# 1.0     232
# 4.5     225
# 1.5     205
# Name: count, dtype: int64

# %%
df['Transaction Date'].value_counts()
# Out:
# Transaction Date
# 2023-06-16    40
# 2023-02-06    40
# 2023-07-24    39
# 2023-03-13    39
# 2023-07-21    39
# 2023-09-21    39
# 2023-01-05    38
# 2023-01-25    37
# 2023-06-18    37
# 2023-10-22    37
# 2023-04-30    36
# 2023-11-23    36
# 2023-06-30    36
# 2023-01-12    36
# 2023-11-07    36
# 2023-08-07    36
# 2023-10-08    35
# 2023-06-28    35
# 2023-04-06    35
# 2023-03-26    35
# 2023-09-06    35
# 2023-05-18    34
# 2023-12-09    34
# 2023-03-16    34
# 2023-04-20    34
# 2023-08-26    34
# 2023-11-06    34
# 2023-10-26    33
# 2023-04-21    33
# 2023-01-30    33
# 2023-10-19    33
# 2023-12-24    33
# 2023-06-23    33
# 2023-05-05    33
# 2023-06-06    33
# 2023-04-02    33
# 2023-09-10    33
# 2023-08-11    33
# 2023-08-17    33
# 2023-06-01    33
# 2023-01-14    32
# 2023-01-29    32
# 2023-10-20    32
# 2023-12-22    32
# 2023-03-30    32
# 2023-02-15    32
# 2023-06-24    32
# 2023-10-21    32
# 2023-08-14    32
# 2023-05-21    32
# 2023-07-26    32
# ...

# %%
df['Price Per Unit'] = df['Price Per Unit'].ffill()

df['Price Per Unit'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Price Per Unit'].value_counts()
# Out:
# Price Per Unit
# 3.0    2562
# 4.0    2465
# 2.0    1289
# 5.0    1275
# 1.0    1207
# 1.5    1202
# Name: count, dtype: int64

# %%
#df['Total Spent'] = df['Total Spent'].fillna()(df['Total Spent'].mean(), inplace= True)

#df['Total Spent'].isnull().sum()

# %%
# df['Total Spent'] = df['Total Spent']


# display(df['Total Spent'])
# df['Total Spent'].isnull().fillna(df['Total Spent'],inplace=True)


# display(df['Total Spent'])

# %%
df['Total Spent'] = df['Total Spent'].fillna(method = 'bfill')

df['Total Spent']
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15340\2470739174.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Total Spent'] = df['Total Spent'].fillna(method = 'bfill')
# 0        4.0
# 1       12.0
# 2       10.0
# 3       10.0
# 4        4.0
# 5       20.0
# 6        9.0
# 7       16.0
# 8       15.0
# 9       20.0
# 10      25.0
# 11       8.0
# 12       8.0
# 13       5.0
# 14       3.0
# 15      15.0
# 16       4.0
# 17       6.0
# 18      15.0
# 19      12.0
# 20      20.0
# 21      16.0
# 22      12.0
# 23       8.0
# 24      20.0
# 25       5.0
# 26       5.0
# 27      12.0
# 28      20.0
# 29      12.0
# 30      10.0
# 31      16.0
# 32      16.0
# 33       5.0
# 34       8.0
# 35       4.0
# 36      12.0
# 37      10.0
# 38      16.0
# 39       8.0
# 40      12.0
# 41      16.0
# 42      12.0
# 43      12.0
# 44       2.0
# 45      15.0
# 46      12.0
# 47      15.0
# ...

# %%
df['Total Spent'] = df['Total Spent'].fillna(method = 'ffill')

df['Total Spent']
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15340\877036017.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Total Spent'] = df['Total Spent'].fillna(method = 'ffill')
# 0        4.0
# 1       12.0
# 2       10.0
# 3       10.0
# 4        4.0
# 5       20.0
# 6        9.0
# 7       16.0
# 8       15.0
# 9       20.0
# 10      25.0
# 11       8.0
# 12       8.0
# 13       5.0
# 14       3.0
# 15      15.0
# 16       4.0
# 17       6.0
# 18      15.0
# 19      12.0
# 20      20.0
# 21      16.0
# 22      12.0
# 23       8.0
# 24      20.0
# 25       5.0
# 26       5.0
# 27      12.0
# 28      20.0
# 29      12.0
# 30      10.0
# 31      16.0
# 32      16.0
# 33       5.0
# 34       8.0
# 35       4.0
# 36      12.0
# 37      10.0
# 38      16.0
# 39       8.0
# 40      12.0
# 41      16.0
# 42      12.0
# 43      12.0
# 44       2.0
# 45      15.0
# 46      12.0
# 47      15.0
# ...

# %%
df['Total Spent'] = df['Total Spent'].fillna(df['Total Spent'].median())

df['Total Spent']
# Out:
# 0        4.0
# 1       12.0
# 2       10.0
# 3       10.0
# 4        4.0
# 5       20.0
# 6        9.0
# 7       16.0
# 8       15.0
# 9       20.0
# 10      25.0
# 11       8.0
# 12       8.0
# 13       5.0
# 14       3.0
# 15      15.0
# 16       4.0
# 17       6.0
# 18      15.0
# 19      12.0
# 20      20.0
# 21      16.0
# 22      12.0
# 23       8.0
# 24      20.0
# 25       5.0
# 26       5.0
# 27      12.0
# 28      20.0
# 29      12.0
# 30      10.0
# 31      16.0
# 32      16.0
# 33       5.0
# 34       8.0
# 35       4.0
# 36      12.0
# 37      10.0
# 38      16.0
# 39       8.0
# 40      12.0
# 41      16.0
# 42      12.0
# 43      12.0
# 44       2.0
# 45      15.0
# 46      12.0
# 47      15.0
# 48      15.0
# 49       9.0
# 50      15.0
# 51      25.0
# 52      25.0
# 53      12.0
# 54      20.0
# 55       2.0
# 56      15.0
# 57       3.0
# 58      16.0
# 59      15.0
# 60       5.0
# 61       3.0
# 62       4.0
# 63      15.0
# 64      16.0
# 65       6.0
# ...

# %%
df['Transaction Date'] = df['Transaction Date'].ffill()

df['Transaction Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Transaction Date'].nunique()
# Out:
# 365

# %%
df['Total Spent'].value_counts()
# Out:
# Total Spent
# 6.0     1030
# 12.0     992
# 4.0      985
# 3.0      968
# 20.0     788
# 15.0     778
# 8.0      708
# 10.0     549
# 2.0      517
# 5.0      505
# 9.0      498
# 16.0     464
# 25.0     274
# 7.5      248
# 1.0      244
# 4.5      240
# 1.5      212
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Transaction Date    0
# dtype: int64

# %%
df.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373    Coffee         2             2.0          4.0
# 1    TXN_4977031      Cake         4             3.0         12.0
# 2    TXN_4271903    Cookie         4             1.0         10.0
# 3    TXN_7034554     Salad         2             5.0         10.0
# 4    TXN_3160411    Coffee         2             2.0          4.0
# 5    TXN_2602893  Smoothie         5             4.0         20.0
# 6    TXN_4433211   UNKNOWN         3             3.0          9.0
# 7    TXN_6699534  Sandwich         4             4.0         16.0
# 8    TXN_4717867  Sandwich         5             3.0         15.0
# 9    TXN_2064365  Sandwich         5             4.0         20.0
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11
# 5       2023-03-31
# 6       2023-10-06
# 7       2023-10-28
# 8       2023-07-28
# 9       2023-12-31

# %%
df.tail(10)
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 9990    TXN_1538510    Coffee         5             2.0         10.0
# 9991    TXN_3897619  Sandwich         3             4.0         12.0
# 9992    TXN_2739140  Smoothie         4             4.0         16.0
# 9993    TXN_4766549  Smoothie         2             4.0         16.0
# 9994    TXN_7851634   UNKNOWN         4             4.0         16.0
# 9995    TXN_7672686    Coffee         2             2.0          4.0
# 9996    TXN_9659401    Coffee         3             2.0          3.0
# 9997    TXN_5255387    Coffee         4             2.0          8.0
# 9998    TXN_7695629    Cookie         3             2.0          3.0
# 9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#      Transaction Date
# 9990       2023-05-22
# 9991       2023-02-24
# 9992       2023-07-05
# 9993       2023-10-20
# 9994       2023-01-08
# 9995       2023-08-30
# 9996       2023-06-02
# ...

# %%
df.dtypes
# Out:
# Transaction ID              object
# Item                        object
# Quantity                     Int64
# Price Per Unit             float64
# Total Spent                float64
# Transaction Date    datetime64[ns]
# dtype: object

# %%
# missing_values = ['Item']

# for col in missing_values:
#     df[col] = df[col]. fillna(df[col].mod(0))
#     df['Item'] = df['Item'].fillna(df['Item'].mod(0))


# df.isnull().sum()

# %%
plot.figure(figsize=(5,5))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
number_columns = []
for column in df.columns:
# Check data type: int64 = integer, float64 = decimal
    if df[column].dtype in ['Int64', 'float64']:
        number_columns.append(column)
display(number_columns )
# Out:
# ['Quantity', 'Price Per Unit', 'Total Spent']

# %%
text_columns= []
for column in df.columns:
    if df[column].dtype == 'object':
        text_columns.append(column)

display(text_columns)
# Out:
# ['Transaction ID', 'Item']

# %%
# text_columns = []
for column in text_columns: 
    if column in df.columns: 
        missing_count = df[column].isnull().sum()
        if missing_count >0:
            print(f"\n Column: {column}") 
        print(f"   Missing values: {missing_count}")
 # Replace common error strings with NaN first df_final[column] = df_final[column].replace(['ERROR', 'UNKNOWN', 'error', 'unknown'], np.nan) # Show unique values before filling print(f"   Unique values before: {df_final[column].nunique()}") print(f"   Sample values: {df_final[column].dropna().unique()[:5]}") # Calculate mode (most frequent value) 

df['Item'] = df['Item'].replace(['ERROR', 'UNKNOWN', 'error', 'unknown'], np.nan)



df['Item'].value_counts().unique()


# Show unique values before filling
print(f"   Unique values before: {df[column].nunique()}")
print(f"   Sample values: {df[column].dropna().unique()[:8]}")
# Out:
#    Missing values: 0
#
#  Column: Item
#    Missing values: 659
#    Unique values before: 8
#    Sample values: ['Coffee' 'Cake' 'Cookie' 'Salad' 'Smoothie' 'Sandwich' 'Juice' 'Tea']

# %%
# Calculate mode (most frequent value)

mode_values = df[column].mode()[0]

display(f'most frequent values :', mode_values)

mode_values1= df[column].value_counts()


display(f'sum of mode values :',mode_values1)

df['Item'].isnull().value_counts()
# Out:
# 'most frequent values :'
# 'Juice'
# 'sum of mode values :'
# Item
# Juice       1215
# Coffee      1204
# Salad       1179
# Cake        1176
# Sandwich    1168
# Smoothie    1139
# Cookie      1130
# Tea         1130
# Name: count, dtype: int64
# Item
# False    9341
# True      659
# Name: count, dtype: int64

# %%
df['Item'].isnull().value_counts()

df['Item'] = df['Item'].fillna(value= 'Juice')

# %%
df['Item'].isnull().sum()
# Out:
# np.int64(0)

# %%
date_columns= []
for column in df.columns:
    if df[column].dtype == 'datetime64[ns]':
        date_columns.append(column)

display(date_columns)
# Out:
# ['Transaction Date']

# %%
df.dtypes
# Out:
# Transaction ID              object
# Item                        object
# Quantity                     Int64
# Price Per Unit             float64
# Total Spent                float64
# Transaction Date    datetime64[ns]
# dtype: object

# %%
df['Price Per Unit'].head(20)
# Out:
# 0     2.0
# 1     3.0
# 2     1.0
# 3     5.0
# 4     2.0
# 5     4.0
# 6     3.0
# 7     4.0
# 8     3.0
# 9     4.0
# 10    5.0
# 11    4.0
# 12    4.0
# 13    1.0
# 14    1.5
# 15    5.0
# 16    4.0
# 17    3.0
# 18    3.0
# 19    3.0
# Name: Price Per Unit, dtype: float64

# %%
df['Total Spent'].head(20)
# Out:
# 0      4.0
# 1     12.0
# 2     10.0
# 3     10.0
# 4      4.0
# 5     20.0
# 6      9.0
# 7     16.0
# 8     15.0
# 9     20.0
# 10    25.0
# 11     8.0
# 12     8.0
# 13     5.0
# 14     3.0
# 15    15.0
# 16     4.0
# 17     6.0
# 18    15.0
# 19    12.0
# Name: Total Spent, dtype: float64
