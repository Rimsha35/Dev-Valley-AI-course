# %% [markdown]
# Objective: Create a program that uses functions to perform basic statistical calculations on a list of numbers.
# Instructions:
# 1. Write a function get_numbers() that asks the user to enter numbers separated by spaces and returns them as a list of floats.
# 2. Write a function calculate_mean(data) that returns the mean (average).
# 3. Write a function calculate_variance(data, mean) that calculates sample variance.
# 4. Write a function calculate_std_dev(variance) that returns the square root of the variance.
# 5. In the main program:
#    - Call get_numbers()
#    - Call calculate_mean()
#    - Call calculate_variance()
#    - Call calculate_std_dev()
#    - Print results in formatted output.
#    Example Output:Enter numbers separated by spaces: 10 12 23 23 16 23 21 16
#     --- Statistical Analysis ---
#     Data: [10.0, 12.0, 23.0, 23.0, 16.0, 23.0, 21.0, 16.0]
#         Mean: 18.0
#         Variance: 24.57
#         Standard Deviation: 4.96---------------------------

# %%
# 1. Write a function get_numbers() that asks the user to enter numbers separated by spaces and returns them as a list of floats.

def get_numbers():
    number = input('Enter a number seperated by spaces')
    return list(map(float, number.split()))

# my_number = get_numbers()
# print('List of float',my_number)

# %%
# 2. Write a function calculate_mean(data) that returns the mean (average).

def calculate_mean(data):
    return sum(data) / len(data)

# data_mean = calculate_mean(data)
# print('the mean', data_mean)

# %%
#3. Write a function calculate_variance(data, mean) that calculates sample variance.

def calculate_variance(data, mean):
    n = len(data)
    return sum((x - mean) ** 2 for x in data) / (n - 1)


# cal_variance = calculate_variance(data, mean)

# print(cal_variance)

# %%
len(data)
# Out:
# 8

# %%
# 4. Write a function calculate_std_dev(variance) that returns the square root of the variance.

import math

def calculate_std_dev(variance):
    return math.sqrt(variance)

# standard_deviation = calculate_std_dev(variance)
# print('the square root of the variance: ', standard_deviation)

# %%
# 5. In the main program:
#    - Call get_numbers() 
#    - Call calculate_mean()   
#    - Call calculate_variance()   
#    - Call calculate_std_dev()   
#    - Print results in formatted output. 
#    Example Output:Enter numbers separated by spaces: 10 12 23 23 16 23 21 16
#     --- Statistical Analysis ---
#     Data: [10.0, 12.0, 23.0, 23.0, 16.0, 23.0, 21.0, 16.0]
#         Mean: 18.0
#         Variance: 24.57
#         Standard Deviation: 4.96---------------------------


my_number = get_numbers()
print('List of float:',my_number)


data_mean = calculate_mean(data)
print('the mean:', data_mean)

cal_variance = calculate_variance(data, mean)
print('Variance of the mean data:',cal_variance)


standard_deviation = calculate_std_dev(variance)
print('the square root of the variance: ', standard_deviation)
# Out:
# List of float: [12.0, 34.0, 56.0, 77.0]
# the mean: 121.25
# Variance of the mean data: 96071.92857142857
# the square root of the variance:  309.95472019543206
